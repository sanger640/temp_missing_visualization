# %%
import pandas as pd
import missingno as msno

# %%
df = pd.read_csv("TripsWithMissing.csv")

# %%
msno.matrix(df.sample(34608))
# Out:
# <AxesSubplot:>

# %%
df_a = pd.read_feather('df_-1')

# %%
msno.matrix(df_a)
# Out:
# <AxesSubplot:>
